# %% [markdown]
# A Stefanini, juntamente com o programa aeroespacial da Agência NASTEFA, estão investigando uma nave espacial que veio de outro planeta. Espalhadas dentro da nave foram encontradas várias letras.
#
# Um grupo de cientistas da própria Stefanini encontrou um padrão com a linguagem Suméria e começou a decifrar, mas todos os cientistas foram abduzidos e agora, para saber onde os cientistas foram e descobrir qual civilização os abduziu, devem terminar de decifrar as imagens das letras.

# %%
import tensorflow as tf; 
print(tf.__version__)
# Out:
# /Users/paulocotta/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/paulocotta/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/paulocotta/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/paulocotta/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# 1.5.0

# %%
### Imports
from PIL import Image, ImageFilter
import os

# %% [markdown]
# Será apresentado neste momento o DataSet do alfabeto atual nosso:

# %%
for name in os.listdir('./dataset/alfabeto'):
    path = './dataset/alfabeto/' + name
    print(path)
    image = Image.open(path)
    image.show()

# %% [markdown]
# Será apresentado neste momento o DataSet do alfabeto baseado em Sumerio mas que não foi encontrado ainda que lingua é e o que foi encontrado na Nave alienigena:

# %%
for name in os.listdir('./dataset/sumerio'):
    path = './dataset/sumerio/' + name
    print(path)
    image = Image.open(path)
    image.show()

# %% [markdown]
# Os dados que foram encontrados o padrão do DE e PARA cada linguagem:

# %%
for name in os.listdir('./dataset/encontrado'):
    path = './dataset/encontrado/' + name
    print(path)
    image = Image.open(path)
    image.show()

# %% [markdown]
# **Primeiro exercício: **
#
# De acordo com o que foi encontrado devemos encontrar o restante do alfabeto. Segue o enigma que devemos descobrir.
#
# Se o alfabeto contém 26 letras e os números contém 0 a 9, sendo o 0 neutro, devemos contabilizar então que temos 9 números, agora devemos identificar as letras faltantes para identificar o texto que foi apresentado na questão três.

# %%
### Deve-se colocar o código aqui

# %% [markdown]
# Após identificar, deve-se explicar qual foi a técnica e a lógica que foi utilizada.
#
# **Explicar aqui**

# %% [markdown]
# **Segundo exercício:**
#
# Deve-se criar uma I.A (Machine Learning ou Deep Learning) para classificar o que é alfabeto Latino Americano e o que é alfabeto alienigena, esse classificador tem que ser dividido em treino, teste e validação. Sugestão é fazer um Data Augmentation para aumentar o DataSet o suficiente para conseguir classificar.
#
# **Dicas:**
#
# - Faça um Data Augumentation
# - Faça padding das imagens para padronizar elas para o mesmo tamanho
# - Utilize alguma técnica que consiga classificar, mas deve explicar o porque e o motivo que foi utilizado

# %%
### O código deve estar contido aqui...

# %% [markdown]
# **Terceiro Exercício:**
#
# Tem um texto que será apresentado abaixo, o mesmo seguindo a lógica do primeiro exercício, faça a tradução do mesmo, identificando as imagens e apresente aqui. Após isso deve-se transforma o texto que está em imagem em texto, utilizando as labels de cada letra, se as letras do alfabeto alienigena não estiver com as labels certas, deve-se corrigir e após isso executar todo o exercício descrito.

# %%
path = './dataset/mensagem.png'
image = Image.open(path)
image.show()

# %%
### O código deve estar aqui...
